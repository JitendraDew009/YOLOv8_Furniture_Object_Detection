# %%
# !pip install ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pathlib import Path
import random, shutil
import matplotlib.pyplot as plt
import torch, yaml
from ultralytics import YOLO

DEVICE = 0 if torch.cuda.is_available() else "cpu"
print("Device:", DEVICE)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 5
#       3 import matplotlib.pyplot as plt
#       4 import torch, yaml
# ----> 5 from ultralytics import YOLO
#       7 DEVICE = 0 if torch.cuda.is_available() else "cpu"
#       8 print("Device:", DEVICE)
#
# ModuleNotFoundError: No module named 'ultralytics'

# %%
ZIP_FILE = "Furniture.v1-furnitureobjects.yolov8"
DATASET = Path("D:\AI Engineer\Datamites\Computer Vision\Object_detection-20260322T154317Z-1-001\Object_detection\Furniture.v1-furnitureobjects.yolov8")

if not DATASET.exist():
    shutil.unpack_archive(ZIP_FILE,".")
print("Dataset folder:", DATSET.resolved())
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\A'
# <>:2: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\Jitendra Dewangan\AppData\Local\Temp\ipykernel_3120\2329530631.py:2: SyntaxWarning: invalid escape sequence '\A'
#   DATASET = Path("D:\AI Engineer\Datamites\Computer Vision\Object_detection-20260322T154317Z-1-001\Object_detection\Furniture.v1-furnitureobjects.yolov8")
# C:\Users\Jitendra Dewangan\AppData\Local\Temp\ipykernel_3120\2329530631.py:2: SyntaxWarning: invalid escape sequence '\A'
#   DATASET = Path("D:\AI Engineer\Datamites\Computer Vision\Object_detection-20260322T154317Z-1-001\Object_detection\Furniture.v1-furnitureobjects.yolov8")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 4
#       1 ZIP_FILE = "Furniture.v1-furnitureobjects.yolov8"
# ...
